# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn import datasets
# %matplotlib inline

# %%
np.random.seed(0)

n_pts = 500

X, y = datasets.make_circles(n_samples = n_pts, random_state = 123, noise =  0.1, factor = 0.2)
X.shape,y.shape
# Out:
# ((500, 2), (500,))

# %%
plt.scatter(X[y == 0, 0], X[y == 0, 1])
plt.scatter(X[y == 1, 0], X[y == 1, 1])
plt.show()

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Dense(units = 4 , activation = "sigmoid",input_shape = (2,)))
model.add(tf.keras.layers.Dense(1, activation = "sigmoid"))

model.compile(tf.keras.optimizers.Adam(learning_rate = 0.01), loss = "binary_crossentropy", metrics = ["accuracy"])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 4)                 12
#
#  dense_6 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 17
# Trainable params: 17
# Non-trainable params: 0
# _________________________________________________________________

# %%
h = model.fit(X,y,verbose = 1, batch_size = 20 , epochs = 100, shuffle = True)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6999 - accuracy: 0.5900
# Epoch 2/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6958 - accuracy: 0.4320
# Epoch 3/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6953 - accuracy: 0.5820
# Epoch 4/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6966 - accuracy: 0.4520
# Epoch 5/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6938 - accuracy: 0.5960
# Epoch 6/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6939 - accuracy: 0.3600
# Epoch 7/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6953 - accuracy: 0.6180
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.4960
# Epoch 9/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6921 - accuracy: 0.3860
# Epoch 10/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6923 - accuracy: 0.4840
# Epoch 11/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6945 - accuracy: 0.6260
# Epoch 12/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6909 - accuracy: 0.4280
# Epoch 13/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6914 - accuracy: 0.3720
# Epoch 14/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6918 - accuracy: 0.6180
# Epoch 15/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6849 - accuracy: 0.6400
# Epoch 16/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6811 - accuracy: 0.6760
# Epoch 17/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6736 - accuracy: 0.7640
# Epoch 18/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6621 - accuracy: 0.8720
# Epoch 19/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6468 - accuracy: 0.9160
# Epoch 20/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6271 - accuracy: 0.8640
# Epoch 21/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.6050 - accuracy: 0.8760
# Epoch 22/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5781 - accuracy: 0.8720
# Epoch 23/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5507 - accuracy: 0.8840
# Epoch 24/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5216 - accuracy: 0.8880
# Epoch 25/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4929 - accuracy: 0.8840
# Epoch 26/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4641 - accuracy: 0.8900
# Epoch 27/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4367 - accuracy: 0.9160
# Epoch 28/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4107 - accuracy: 0.9280
# Epoch 29/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.3853 - accuracy: 0.9420
# Epoch 30/100
# 25/25 [==============================] - 0s 6ms/step - loss: 0.3615 - accuracy: 0.9520
# Epoch 31/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3390 - accuracy: 0.9600
# Epoch 32/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3174 - accuracy: 0.9780
# Epoch 33/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2974 - accuracy: 0.9820
# Epoch 34/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2788 - accuracy: 0.9860
# Epoch 35/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2619 - accuracy: 0.9920
# Epoch 36/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2455 - accuracy: 0.9960
# Epoch 37/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2311 - accuracy: 1.0000
# Epoch 38/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2179 - accuracy: 1.0000
# Epoch 39/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2055 - accuracy: 1.0000
# Epoch 40/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1945 - accuracy: 1.0000
# Epoch 41/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1846 - accuracy: 1.0000
# Epoch 42/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1753 - accuracy: 1.0000
# Epoch 43/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1668 - accuracy: 1.0000
# Epoch 44/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1590 - accuracy: 1.0000
# Epoch 45/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1520 - accuracy: 1.0000
# Epoch 46/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1455 - accuracy: 1.0000
# Epoch 47/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1392 - accuracy: 1.0000
# Epoch 48/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1337 - accuracy: 1.0000
# Epoch 49/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1284 - accuracy: 1.0000
# Epoch 50/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1235 - accuracy: 1.0000
# Epoch 51/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1190 - accuracy: 1.0000
# Epoch 52/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1146 - accuracy: 1.0000
# Epoch 53/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1104 - accuracy: 1.0000
# Epoch 54/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1066 - accuracy: 1.0000
# Epoch 55/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.1031 - accuracy: 1.0000
# Epoch 56/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0997 - accuracy: 1.0000
# Epoch 57/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0964 - accuracy: 1.0000
# Epoch 58/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0933 - accuracy: 1.0000
# Epoch 59/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0905 - accuracy: 1.0000
# Epoch 60/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0877 - accuracy: 1.0000
# Epoch 61/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0850 - accuracy: 1.0000
# Epoch 62/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0824 - accuracy: 1.0000
# Epoch 63/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0800 - accuracy: 1.0000
# Epoch 64/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0779 - accuracy: 1.0000
# Epoch 65/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0755 - accuracy: 1.0000
# Epoch 66/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0735 - accuracy: 1.0000
# Epoch 67/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0714 - accuracy: 1.0000
# Epoch 68/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0695 - accuracy: 1.0000
# Epoch 69/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0677 - accuracy: 1.0000
# Epoch 70/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0659 - accuracy: 1.0000
# Epoch 71/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0641 - accuracy: 1.0000
# Epoch 72/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0625 - accuracy: 1.0000
# Epoch 73/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0609 - accuracy: 1.0000
# Epoch 74/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0594 - accuracy: 1.0000
# Epoch 75/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0579 - accuracy: 1.0000
# Epoch 76/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0565 - accuracy: 1.0000
# Epoch 77/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0552 - accuracy: 1.0000
# Epoch 78/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0538 - accuracy: 1.0000
# Epoch 79/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 1.0000
# Epoch 80/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0513 - accuracy: 1.0000
# Epoch 81/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0501 - accuracy: 1.0000
# Epoch 82/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0489 - accuracy: 1.0000
# Epoch 83/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0478 - accuracy: 1.0000
# Epoch 84/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 85/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 86/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0446 - accuracy: 1.0000
# Epoch 87/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0437 - accuracy: 1.0000
# Epoch 88/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 89/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0418 - accuracy: 1.0000
# Epoch 90/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0409 - accuracy: 1.0000
# Epoch 91/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 92/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0392 - accuracy: 1.0000
# Epoch 93/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 94/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 95/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 96/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 97/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 98/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 99/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 100/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0332 - accuracy: 1.0000

# %%
plt.figure(figsize = (15,5))

plt.subplot(121)
plt.plot(h.history["accuracy"], label = "accuracy",color ="blue") 
plt.legend(loc = "best")

plt.subplot(122)
plt.plot(h.history["loss"], label = "loss",color = "orange") 
plt.legend(loc = "best")

plt.tight_layout()
plt.show()

# %%
def plot_decision_boundary(X,y,model):

    x_span = np.linspace(min(X[:,0]) - 0.25, max(X[:,0]) + 0.25, 50)
    y_span = np.linspace(min(X[:,1]) - 0.25, max(X[:,1]) + 0.25, 50)

    xx,yy = np.meshgrid(x_span,y_span)
    xx_,yy_ = xx.ravel(),yy.ravel()

    grid = np.c_[xx_,yy_]
    pred_func = model.predict(grid)
    z = pred_func.reshape(xx.shape)
    plt.contourf(xx,yy,z)

# %%
plt.figure(figsize = (10,7))

plot_decision_boundary(X,y,model)
plt.scatter(X[y == 0, 0], X[y == 0, 1])
plt.scatter(X[y == 1, 0], X[y == 1, 1])

x = 0.1
y = 0.1
point = np.array([[x,y]])
pred = model.predict(point)
print("Prediction is : ", pred[0][0])

plt.plot([x],[y],marker = "o", markersize = 10, color = "red")
plt.show()
# Out:
# Prediction is :  0.98405576
