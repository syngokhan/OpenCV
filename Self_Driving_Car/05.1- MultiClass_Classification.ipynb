# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn import datasets
import tensorflow as tf

# %%
n_pts = 500

centers = [[-1,1] , [-1,-1], [1,-1]]
X,y = datasets.make_blobs(n_samples = n_pts, random_state = 123, centers = centers , cluster_std=0.4)
X.shape,y.shape
# Out:
# ((500, 2), (500,))

# %%
centers = [[-1,1] , [-1,-1], [1,-1]]

plt.figure(figsize = (7,5))

plt.scatter(X[y == 0, 0], X[y==0, 1])
plt.scatter(X[y == 1, 0], X[y==1, 1])
plt.scatter(X[y == 2, 0], X[y==2, 1])

plt.show()

# %%
pd.Series(y).unique()
# Out:
# array([2, 0, 1])

# %%
y_cat = tf.keras.utils.to_categorical(y,3)
y_cat.shape
# Out:
# (500, 3)

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Dense(units = 3, input_shape = (2,), activation = "softmax"))

model.compile(tf.keras.optimizers.Adam(learning_rate = 0.2), loss = "categorical_crossentropy", metrics = ["accuracy"])

h = model.fit(X,y_cat, verbose = 1, epochs = 100, batch_size = 50)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 3ms/step - loss: 0.2734 - accuracy: 0.9540
# Epoch 2/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0630 - accuracy: 0.9860
# Epoch 3/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0451 - accuracy: 0.9880
# Epoch 4/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 0.9880
# Epoch 5/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 0.9900
# Epoch 6/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0350 - accuracy: 0.9880
# Epoch 7/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0344 - accuracy: 0.9880
# Epoch 8/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0331 - accuracy: 0.9900
# Epoch 9/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0321 - accuracy: 0.9880
# Epoch 10/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0314 - accuracy: 0.9900
# Epoch 11/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 0.9900
# Epoch 12/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0312 - accuracy: 0.9900
# Epoch 13/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0301 - accuracy: 0.9900
# Epoch 14/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0300 - accuracy: 0.9900
# Epoch 15/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0298 - accuracy: 0.9900
# Epoch 16/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0291 - accuracy: 0.9900
# Epoch 17/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0291 - accuracy: 0.9900
# Epoch 18/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0290 - accuracy: 0.9900
# Epoch 19/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9880
# Epoch 20/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0286 - accuracy: 0.9900
# Epoch 21/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9900
# Epoch 22/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0291 - accuracy: 0.9900
# Epoch 23/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 0.9900
# Epoch 24/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0275 - accuracy: 0.9900
# Epoch 25/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9900
# Epoch 26/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 0.9880
# Epoch 27/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9900
# Epoch 28/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0272 - accuracy: 0.9900
# Epoch 29/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9900
# Epoch 30/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9900
# Epoch 31/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 0.9900
# Epoch 32/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 0.9900
# Epoch 33/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0268 - accuracy: 0.9880
# Epoch 34/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9880
# Epoch 35/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9900
# Epoch 36/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9900
# Epoch 37/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9900
# Epoch 38/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9900
# Epoch 39/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0260 - accuracy: 0.9900
# Epoch 40/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0277 - accuracy: 0.9900
# Epoch 41/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0285 - accuracy: 0.9900
# Epoch 42/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0266 - accuracy: 0.9880
# Epoch 43/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 0.9900
# Epoch 44/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0271 - accuracy: 0.9900
# Epoch 45/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 0.9920
# Epoch 46/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0270 - accuracy: 0.9900
# Epoch 47/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9900
# Epoch 48/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 0.9900
# Epoch 49/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9900
# Epoch 50/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9900
# Epoch 51/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9900
# Epoch 52/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 0.9900
# Epoch 53/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 0.9900
# Epoch 54/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0274 - accuracy: 0.9900
# Epoch 55/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 0.9920
# Epoch 56/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 0.9900
# Epoch 57/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 0.9900
# Epoch 58/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 0.9900
# Epoch 59/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0261 - accuracy: 0.9900
# Epoch 60/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0279 - accuracy: 0.9920
# Epoch 61/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 0.9900
# Epoch 62/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0264 - accuracy: 0.9900
# Epoch 63/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0264 - accuracy: 0.9900
# Epoch 64/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9900
# Epoch 65/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0248 - accuracy: 0.9920
# Epoch 66/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0259 - accuracy: 0.9900
# Epoch 67/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9900
# Epoch 68/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 0.9920
# Epoch 69/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0255 - accuracy: 0.9900
# Epoch 70/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9900
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0263 - accuracy: 0.9900
# Epoch 72/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0260 - accuracy: 0.9900
# Epoch 73/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0278 - accuracy: 0.9880
# Epoch 74/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 0.9920
# Epoch 75/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9900
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 0.9900
# Epoch 77/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 0.9880
# Epoch 78/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 0.9900
# Epoch 79/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 0.9900
# Epoch 80/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0259 - accuracy: 0.9900
# Epoch 81/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0242 - accuracy: 0.9920
# Epoch 82/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0243 - accuracy: 0.9920
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0265 - accuracy: 0.9880
# Epoch 84/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9900
# Epoch 85/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0252 - accuracy: 0.9920
# Epoch 86/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9920
# Epoch 87/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9900
# Epoch 88/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 0.9900
# Epoch 89/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0241 - accuracy: 0.9920
# Epoch 90/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0249 - accuracy: 0.9920
# Epoch 91/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0250 - accuracy: 0.9900
# Epoch 92/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0247 - accuracy: 0.9880
# Epoch 93/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 0.9900
# Epoch 94/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0243 - accuracy: 0.9900
# Epoch 95/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0258 - accuracy: 0.9920
# Epoch 96/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0240 - accuracy: 0.9900
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 0.9920
# Epoch 98/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 0.9900
# Epoch 99/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9900
# Epoch 100/100
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 0.9920

# %%
plt.figure(figsize = (15,5))

plt.subplot(121)
plt.plot(h.history["accuracy"], label = "accuracy",color ="blue") 
plt.legend(loc = "best")

plt.subplot(122)
plt.plot(h.history["loss"], label = "loss",color = "orange") 
plt.legend(loc = "best")

plt.tight_layout()
plt.show()

# %%
def plot_decision_boundary(X,y_cat,model):

    x_span = np.linspace(min(X[:, 0 ]) - 1 , max(X[:, 0]) + 1, 50)
    y_span = np.linspace(min(X[:, 0 ]) - 1 , max(X[:, 0]) + 1, 50)

    xx, yy = np.meshgrid(x_span,y_span)

    xx_,yy_ = xx.ravel(),yy.ravel()

    grid = np.c_[xx_,yy_]

    pred_func = model.predict(grid)
    pred_func = np.argmax(pred_func, axis = 1)

    z = pred_func.reshape(xx.shape)

    plt.contourf(xx,yy,z)

# %%
plt.figure(figsize = (7,5))

plot_decision_boundary(X,y_cat, model)

plt.scatter(X[y == 0, 0], X[y == 0, 1])
plt.scatter(X[y == 1, 0], X[y == 1, 1])
plt.scatter(X[y == 2, 0], X[y == 2, 1])

x = 0.5
y = -1

points = np.array([[x,y]])
pred = np.argmax(model.predict(points))

plt.plot([x],[y],marker = "o",markersize = 10, color = "red")
print("Prediction is :",pred)

plt.show()
# Out:
# Prediction is : 2
