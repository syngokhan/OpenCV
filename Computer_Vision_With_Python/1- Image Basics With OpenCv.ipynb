# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Opening Image Files In A Notebook

# %%
import cv2

# %%
path = "DATA/00-puppy.jpg"

img = cv2.imread(path)
type(img)
# Out:
# numpy.ndarray

# %%
# Yanlış veride hata göstermez 

img = cv2.imread("wrong/path/adsadds.jpg")
type(img)
# Out:
# NoneType

# %%
img = cv2.imread(path)
img.shape
# Out:
# (1300, 1950, 3)

# %%
# Matplotlib --- > RGB RED GREEN BLUE
# OPENCV --- > BLUE GREEN RED

# %%
plt.imshow(img)
plt.show()

# %%
# Biz normalde bunu open cv okuduk ve BGR olarak çıkıyor biz bunu matplotlib uygun olması için
# BGR -- > RGB çeviriyoruz !!!

fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)
plt.show()

# %%
gray_img = cv2.imread(filename = path,flags = cv2.IMREAD_GRAYSCALE)
print("Gray Img Shape : {}".format(gray_img.shape))
print("Max Values : {}".format(gray_img.max()))
print("Min Values : {}".format(gray_img.min()))
# Out:
# Gray Img Shape : (1300, 1950)
# Max Values : 209
# Min Values : 1

# %%
# Default cmap = "viridis"
plt.imshow(gray_img,cmap = "gray")
plt.show()

# %%
gray_img_ = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gray_img,cmap = "gray")
plt.show()

# %%
# For Resize and Repeat
img = cv2.imread(filename = path)
fix_img = cv2.cvtColor( src = img, code = cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)
plt.show()

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
# Resize

resize_img = cv2.resize(src = fix_img, dsize = (1000,400))
plt.imshow(resize_img)
plt.show()

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
w_ratio = 0.8
h_ratio = 0.5 # 20% of original height 

ratio_img = cv2.resize(src = fix_img, dsize = (0,0), dst =fix_img, fx  = w_ratio, fy = h_ratio )

plt.imshow(ratio_img)
plt.show()

# %%
flip_img = cv2.flip(fix_img,0)
plt.imshow(flip_img)
plt.show()

# %%
cv2.imwrite("Data/Totally_new.jpg",fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize = (10,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
plt.show()

# %%
plt.figure(figsize = (10,10))
plt.imshow(fix_img)
plt.show()

# %% [markdown]
# ## Opening Image Files With OpenCV2

# %%
import cv2
import numpy

# %%
path = "DATA/00-puppy.jpg"
img = cv2.imread(path)

cv2.imshow(winname = "Puppy",mat = img)
cv2.waitKey()

# %%
path = "DATA/00-puppy.jpg"
img = cv2.imread(filename = path)

while True:
    
    cv2.imshow(winname = "Puppy", mat = img)
    
    # If we've waited at least 1 ms and we've pressed the ESC
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cv2.destroyAllWindows()

# %% [markdown]
# ## Drawing On Images

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
blank_img = np.zeros(shape = (512,512,3), dtype = np.int16)
blank_img.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(blank_img)
plt.show()

# %%
blank_img = np.zeros(shape = (512,512,3), dtype = np.int16)
rec1_img = cv2.rectangle(img = blank_img, pt1 = (200,90), pt2 = (510,150), color = (0,255,0), thickness = 10)
plt.figure(figsize = (15,6))
plt.imshow(new_img)
plt.show()

# %%
rec2_img = cv2.rectangle(img = rec1_img, pt1 = (200,200), pt2 = (300,300),color = (0,0,255), thickness = 10)
plt.figure(figsize = (15,6))
plt.imshow(rec2_img)
plt.show()

# %%
# Burda illa bir değere eşitlemeden üstüne yazıyor zaten !!!!

cv2.circle(img = rec2_img, center =(100,100),radius = 50, color = (255,0,0),thickness = 10)
plt.figure(figsize = (15,6))
plt.imshow(rec2_img)
plt.show()

# %%
cv2.circle(img = rec2_img, center =(400,400),radius = 50, color = (255,0,0),thickness = -1)
plt.figure(figsize = (15,6))
plt.imshow(rec2_img)
plt.show()

# %%
cv2.line(img = rec2_img, pt1 = (0,500), pt2 = (512,500), color = (102,255,255),thickness = 5)
plt.figure(figsize = (15,6))
plt.imshow(rec2_img)
plt.show()

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(rec2_img, text = "Hello", org = (10,400), fontFace = font, fontScale = 4, color = (255,255,255),
           thickness = 3, lineType=cv2.LINE_AA)

plt.figure(figsize = (15,6))
plt.imshow(rec2_img)
plt.show()

# %%
blank_img = np.zeros(shape = (512,512,3), dtype = np.int32)

plt.figure(figsize = (15,6))
plt.imshow(blank_img)
plt.show()

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]] , np.int32)

# %%
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
vertices.shape
# Out:
# (4, 2)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
pts.shape
# Out:
# (4, 1, 2)

# %%
cv2.polylines(img = blank_img, pts = [pts], isClosed = True, color = (255,0,0), thickness=5)
plt.figure(figsize = (15,6))
plt.imshow(blank_img)
plt.show()

# %% [markdown]
# ## Direct Drawing With Mouse

# %%
import cv2
import numpy as np

############################# 
# Function
############################# 


def draw_circle(event, x, y, flags, param):
    
    if event == cv2.EVENT_LBUTTONDOWN:
    
        cv2.circle(img = img, center = (x,y), radius = 100, color = (0,255,0), thickness = -1)
    
    elif event == cv2.EVENT_RBUTTONDOWN:
        
        cv2.circle(img = img, center = (x,y), radius = 100, color = (255,0,0), thickness = -1)

cv2.namedWindow(winname = "my_drawing")

cv2.setMouseCallback("my_drawing",draw_circle)


#############################
## Showing Image With OpenCV
############################# 


img = np.zeros((512,512,3))

while True:
    
    cv2.imshow("my_drawing",img)
    
    if cv2.waitKey(20) & 0xFF == ord("q"):
        break
        
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np


############################# 
# Variables
############################# 

# True while mouse button down, False while mouse button up

drawing = False

ix = -1
iy = -1

############################# 
# Function
############################# 

def draw_rectangle(event,x,y,flags,params):
    
    global ix,iy,drawing
    
    if event == cv2.EVENT_LBUTTONDOWN:
        
        drawing = True
        ix,iy = x, y
        
    elif event == cv2.EVENT_MOUSEMOVE:
        
        if drawing == True:
            
            cv2.rectangle(img = img, pt1 = (ix,iy), pt2 = (x,y), color = (0,255,0), thickness = -1 )
            
    elif event == cv2.EVENT_LBUTTONUP:
        
        drawing = False
        
        cv2.rectangle(img = img, pt1 = (ix,iy), pt2 = (x,y), color = (0,255,0), thickness = -1)
        
#############################
## Showing Image With OpenCV
############################# 

img = np.zeros((512,512,3))

cv2.namedWindow(winname = "my_drawing")

cv2.setMouseCallback("my_drawing", draw_rectangle)

while True:
    
    cv2.imshow(winname = "my_drawing",mat = img)
    
    if cv2.waitKey(delay = 1) & 0xFF == ord("q"):
        break
        
cv2.destroyAllWindows()
