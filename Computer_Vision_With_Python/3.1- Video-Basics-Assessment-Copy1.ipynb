# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../DATA/Logo.jpg"></a>
#
# <em text-align:center>Copyright Pierian Data Inc.</em>

# %% [markdown]
# # Video Basics Assessment
#
# * **Note: This assessment is quite hard! Feel free to treat it as a code along and jump to the solutions** *
#
# ## Project Task
#
# **You only have one task here. Create a program that reads in a live stream from a camera on your computer (or if you don't have a camera, just open up a video file). Then whenever you click the left mouse button down, create a blue circle around where you've clicked. Check out the video for an example of what the final project should look like**

# %% [markdown]
# **Guide**
#
# * Create a draw_circle function for the callback function
# * Use two events cv2.EVENT_LBUTTONDOWN and cv2.EVENT_LBUTTONUP
# * Use a boolean variable to keep track if the mouse has been clicked up and down based on the events above
# * Use a tuple to keep track of the x and y where the mouse was clicked.
# * You should be able to then draw a circle on the frame based on the x,y coordinates from the Event
#
# Check out the skeleton guide below:

# %%
# Create a function based on a CV2 Event (Left button click)
import cv2


# mouse callback function
def draw_circle(event,x,y,flags,param):

    global center,clicked

    # get mouse click on down and track center
    
    if event == cv2.EVENT_LBUTTONDOWN:
        
        center = (x,y)
        clicked = False
        
    elif event == cv2.EVENT_LBUTTONUP:
        
        clicked = True
        
    
    
    # Use boolean variable to track if the mouse has been released
   


 # Haven't drawn anything yet!

center = (0,0)
clicked = False


# Capture Video

cap = cv2.VideoCapture(0)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
heigth = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

fps = 30
writer = cv2.VideoWriter("cirle.mp4",cv2.VideoWriter_fourcc(*"XVID"),fps,(width,heigth))


# Create a named window for connections

cv2.namedWindow("Test")

# Bind draw_rectangle function to mouse cliks

cv2.setMouseCallback("Test",draw_circle)


while True:
    # Capture frame-by-frame
    ret,frame = cap.read()
 

    # Use if statement to see if clicked is true
    
    if clicked:
   
        # Draw circle on frame
        cv2.circle(frame,center,50,(255,255,0),5)
        
        
    # Display the resulting frame
    
    writer.write(frame)
    
    cv2.imshow("Test",frame)
    

    # This command let's us quit with the "q" button on a keyboard.
    # Simply pressing X on the window won't work!
    
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

# When everything is done, release the capture

writer.release()
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ---

# %%
import cv2
import numpy as np


def draw_circle(event,x,y,flags,param):
    
    if event == cv2.EVENT_LBUTTONDOWN:
        
        cv2.circle(img,(x,y),100,(0,0,255),5)

path = "DATA/dog_backpack.jpg"
img = cv2.imread(path)

cv2.namedWindow("Circle")
cv2.setMouseCallback("Circle",draw_circle)

while True:
    
    cv2.imshow("Circle",img)
    
    if cv2.waitKey(20) & 0xFF == ord("q"):
        break
        
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

drawing = False
ix = -1
iy = -1

def draw_rectangle(event,x,y,flags,param):
    
    global drawing,ix,iy
    
    if event == cv2.EVENT_LBUTTONDOWN:
            
            drawing = True
            ix,iy = x,y
    
    elif event == cv2.EVENT_MOUSEMOVE:
        
        if drawing == True:
            
            cv2.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
            
    elif event == cv2.EVENT_LBUTTONUP:
        
        drawing = False
        
        cv2.rectangle(img,(ix,iy),(x,y),(0,0,255),-1)
    

img = np.zeros((512,512,3))


cv2.namedWindow("Rectangle")
cv2.setMouseCallback("Rectangle",draw_rectangle)

while True:
    
    cv2.imshow("Rectangle",img)
    
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
        
cv2.destroyAllWindows()

# %% [markdown]
# ----

# %%
import cv2

cap = cv2.VideoCapture(0)

fps = 30

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Windows --> DIVX
# Linux or MacOs --> XVID

writer = cv2.VideoWriter("myvideo.mp4",cv2.VideoWriter_fourcc(*"XVID"),fps,(width,height))


while True:
    
    ret,frame = cap.read()
    
    writer.write(frame)
    
    # gray2img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # cv2.imshow(winname = "deneme",mat = frame)
    
    cv2.imshow("deneme",frame)
    
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
        
cap.release()
writer.release()
cv2.destroyAllWindows()

# %%
import cv2
import time

cap = cv2.VideoCapture("myvideo.mp4")

# Frames Per Second For Video

fps = 30

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
heigth = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

#writer = cv2.VideoWriter("myvideo.mp4",cv2.VideoWriter_fourcc("*XVID"),fps,(width,height))


if cap.isOpened() == False:
    
    print("Error opening the video file.Please double check your file path for types.")
    print("Or move the movie file to the same location as this script/notebook")

    
while cap.isOpened():
    
    ret,frame = cap.read()
    
    if ret:
        
        time.sleep(1/fps)
        cv2.imshow("Deneme",frame)
        
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
        
    else:
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

cap = cv2.VideoCapture(0)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

fps = 30
writer = cv2.VideoWriter("myvideo_new.mp4",cv2.VideoWriter_fourcc(*"XVID"),fps,(width,height))

x = width // 2 
y = height // 2

w = width // 4
h = height // 4

while True:
    
    ret,frame = cap.read()
    
    cv2.rectangle(frame,(x,y),(x+w,y+h),(255,255,255),4)
    
    writer.write(frame)
    
    cv2.imshow("Deneme",frame)
    
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break
        
writer.release()
cap.release()
cv2.destroyAllWindows()

# %%
import cv2

topBottom_clicked = False
botBottom_clicked = False
pt1 = (0,0)
pt2 = (0,0)

def drawing_rectangle(event,x,y,flags,param):
    
    if event == cv2.EVENT_LBUTTONDOWN:
        
        global topBottom_clicked,botBottom_clicked,pt1,pt2
        
        if topBottom_clicked == True and botBottom_clicked == True :
            
            topBottom_clicked = False
            botBottom_clicked = False
            pt1 = (0,0)
            pt2 = (0,0)
            
        if topBottom_clicked == False:
            
            pt1 = (x,y)
            topBottom_clicked = True
        
        elif botBottom_clicked == False:
            
            pt2 = (x,y)
            botBottom_clicked = True

cap = cv2.VideoCapture(0)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

cv2.namedWindow("drawing")
cv2.setMouseCallback("drawing",drawing_rectangle)

while True:
    
    ret,frame = cap.read()
    
    
    if topBottom_clicked:
        
        cv2.circle(frame,pt1,5,(0,0,255),-1)
        
    if topBottom_clicked and botBottom_clicked:
    
        cv2.rectangle(frame,pt1,pt2,(255,0,0),4)
    
    cv2.imshow("drawing",frame)
    
    
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
