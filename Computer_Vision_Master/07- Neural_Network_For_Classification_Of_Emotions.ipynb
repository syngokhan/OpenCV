# %%
import cv2
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import zipfile

from google.colab import drive
from google.colab.patches import cv2_imshow

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/OpenCV/Datasets/fer_images.zip"
zip_object = zipfile.ZipFile(file = path, mode = "r")
zip_object.extractall("./")
zip_object.close()

# %% [markdown]
# # Train and Test Set

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

training_generator = ImageDataGenerator(rescale = 1. / 255,
                                        horizontal_flip = True,
                                        rotation_range = 7,
                                        zoom_range = 0.2)

train_dataset = training_generator.flow_from_directory("/content/fer2013/train",
                                                       shuffle = True,
                                                       target_size = (48,48),
                                                       batch_size = 16,
                                                        class_mode = "categorical")
# Out:
# Found 28709 images belonging to 7 classes.

# %%
test_generator = ImageDataGenerator(rescale = 1. / 255)

test_dataset = test_generator.flow_from_directory("/content/fer2013/validation",
                                                       shuffle = False,
                                                       target_size = (48,48),
                                                       batch_size = 1,
                                                        class_mode = "categorical")
# Out:
# Found 3589 images belonging to 7 classes.

# %%
train_dataset.classes, train_dataset.class_indices
# Out:
# (array([0, 0, 0, ..., 6, 6, 6], dtype=int32),
#  {'Angry': 0,
#   'Disgust': 1,
#   'Fear': 2,
#   'Happy': 3,
#   'Neutral': 4,
#   'Sad': 5,
#   'Surprise': 6})

# %%
np.unique(train_dataset.classes, return_counts = True)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6], dtype=int32),
#  array([3995,  436, 4097, 7215, 4965, 4830, 3171]))

# %%
from warnings import filterwarnings
filterwarnings("ignore")

plt.figure(figsize = (10,5))
sns.countplot(train_dataset.classes)
plt.show()

# %% [markdown]
# # Building and Training The Neural Network

# %%
# Based on: https://github.com/rajeevratan84/DeepLearningCV/blob/master/18.2%20Building%20an%20Emotion%20Detector%20with%20LittleVGG.ipynb
# Padding: https://www.pico.net/kb/what-is-the-difference-between-same-and-valid-padding-in-tf-nn-max-pool-of-tensorflow
# BatchNormalization: https://keras.io/api/layers/normalization_layers/batch_normalization/
# Dropout: https://jmlr.org/papers/volume15/srivastava14a.old/srivastava14a.pdf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,Dropout,Flatten,BatchNormalization,MaxPool2D,Dense

# %%
num_detector = 32
num_classes = 7
width, height = 48,48
epochs = 100

model = Sequential()

model.add(Conv2D(filters = num_detector,kernel_size = (3,3), activation = "relu", padding = "same", input_shape = (width, height,3)))
model.add(BatchNormalization())
model.add(Conv2D(filters = num_detector,kernel_size = (3,3), activation = "relu", padding = "same"))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (2,2)))
model.add(Dropout(rate = 0.2))

model.add(Conv2D(filters = 2*num_detector,kernel_size = (3,3), activation = "relu", padding = "same"))
model.add(BatchNormalization())
model.add(Conv2D(filters = 2*num_detector,kernel_size = (3,3), activation = "relu", padding = "same"))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (2,2)))
model.add(Dropout(rate = 0.2))

model.add(Conv2D(filters = 2*2*num_detector,kernel_size = (3,3), activation = "relu", padding = "same"))
model.add(BatchNormalization())
model.add(Conv2D(filters = 2*2*num_detector,kernel_size = (3,3), activation = "relu", padding = "same"))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (2,2)))
model.add(Dropout(rate = 0.2))

model.add(Conv2D(filters = 2*2*2*num_detector,kernel_size = (3,3), activation = "relu", padding = "same"))
model.add(BatchNormalization())
model.add(Conv2D(filters = 2*2*2*num_detector,kernel_size = (3,3), activation = "relu", padding = "same"))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size = (2,2)))
model.add(Dropout(rate = 0.2))

model.add(Flatten())

model.add(Dense(units = 2* num_detector,activation = "relu"))
model.add(BatchNormalization())
model.add(Dropout(rate = 0.2))

model.add(Dense(units = 2* num_detector,activation = "relu"))
model.add(BatchNormalization())
model.add(Dropout(rate = 0.2))

model.add(Dense(units = num_classes, activation = "softmax"))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_17 (Conv2D)          (None, 48, 48, 32)        896
#
#  batch_normalization_16 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  conv2d_18 (Conv2D)          (None, 48, 48, 32)        9248
#
#  batch_normalization_17 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  dropout_8 (Dropout)         (None, 24, 24, 32)        0
#
#  conv2d_19 (Conv2D)          (None, 24, 24, 64)        18496
#
#  batch_normalization_18 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  conv2d_20 (Conv2D)          (None, 24, 24, 64)        36928
#
#  batch_normalization_19 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_9 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_21 (Conv2D)          (None, 12, 12, 128)       73856
#
#  batch_normalization_20 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  conv2d_22 (Conv2D)          (None, 12, 12, 128)       147584
#
#  batch_normalization_21 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 6, 6, 128)         0
#
#  conv2d_23 (Conv2D)          (None, 6, 6, 256)         295168
#
#  batch_normalization_22 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv2d_24 (Conv2D)          (None, 6, 6, 256)         590080
#
#  batch_normalization_23 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 3, 3, 256)        0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 3, 3, 256)         0
#
#  flatten_2 (Flatten)         (None, 2304)              0
#
#  dense (Dense)               (None, 64)                147520
#
#  batch_normalization_24 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  batch_normalization_25 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_13 (Dropout)        (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 1,328,743
# Trainable params: 1,326,567
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

#history = model.fit(train_dataset, epochs = 100, validation_data= test_dataset)

# %%
model_json_path = "/content/drive/MyDrive/OpenCV/Weights/network_emotions.json"
model_path = "/content/drive/MyDrive/OpenCV/Weights/weights_emotions.hdf5"

with open(model_json_path,"r") as file:
    model_json = file.read()

model_json
# Out:
# '{"class_name": "Sequential", "config": {"name": "sequential_1", "layers": [{"class_name": "InputLayer", "config": {"batch_input_shape": [null, 48, 48, 3], "dtype": "float32", "sparse": false, "ragged": false, "name": "conv2d_8_input"}}, {"class_name": "Conv2D", "config": {"name": "conv2d_8", "trainable": true, "batch_input_shape": [null, 48, 48, 3], "dtype": "float32", "filters": 32, "kernel_size": [3, 3], "strides": [1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1], "groups": 1, "activation": "relu", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "BatchNormalization", "config": {"name": "batch_normalization_8", "trainable": true, "dtype": "float32", "axis": [3], "momentum": 0.99, "epsilon": 0.001, "center": true, "scale": true, "beta_initializer": {"class_name": "Zeros", "config": {}}, "gamma_initializer": {"class_name": "Ones", "config": {}}, "moving_mean_initializer": {"class_name": "Zeros", "config": {}}, "moving_variance_initializer": {"class_name": "Ones", "config": {}}, "beta_regularizer": null, "gamma_regularizer": null, "beta_constraint": null, "gamma_constraint": null}}, {"class_name": "Conv2D", "config": {"name": "conv2d_9", "trainable": true, "dtype": "float32", "filters": 32, "kernel_size": [3, 3], "strides": [1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1], "groups": 1, "activation": "relu", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "BatchNormalization", "config": {"name": "batch_normalization_9", "trainable": true, "dtype": "float32", "axis": [3], "momentum": 0.99, "epsilon": 0.001, "center": true, "scale": true, "beta_initializer": {"class_name": "Zeros", "config": {}}, "gamma_initializer": {"class_name": "Ones", "config": {}}, "moving_mean_initializer": {"class_name": "Zeros", "config": {}}, "moving_variance_initializer": {"class_name": "Ones", "config": {}}, "beta_regularizer": null, "gamma_regularizer": null, "beta_constraint": null, "gamma_constraint": null}}, {"class_name": "MaxPooling2D", "config": {"name": "max_pooling2d_4", "trainable": true, "dtype": "float32", "pool_size": [2, 2], "padding": "valid", "strides": [2, 2], "data_format": "channels_last"}}, {"class_name": "Dropout", "config": {"name": "dropout_4", "trainable": true, "dtype": "float32", "rate": 0.2, "noise_shape": null, "seed": null}}, {"class_name": "Conv2D", "config": {"name": "conv2d_10", "trainable": true, "dtype": "float32", "filters": 64, "kernel_size": [3, 3], "strides": [1, 1], "padding": "same", "data_format": "channels_last", "dilation_rate": [1, 1], "groups": 1, "activation": "relu", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "BatchNormalization", "config": {"name": "batch_normalization_10", "trainable": true, "dtype": "float32", "axis": [3], "momentum": 0.99, "epsilon": 0.001, "center": true, "scale": true, "beta_initializer": {"class_name": "Zeros", "config": {}}, "gamma_initializer": {"class_name": "Ones", "config": {}}, "moving_mean_initializer": {"class_name": "Zeros", "config": {}}, "moving_variance_initializer": {"class_name": "Ones", "config": {}}, "beta_regularizer": null, "gamma_regularizer": null, "beta_constraint": null, "gamma_constraint": null}}, {"class_name": "C ...

# %%
from tensorflow.keras.models import model_from_json

# %%
load_model = model_from_json(model_json)
load_model.load_weights(model_path)
load_model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %%
load_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 48, 48, 32)        896
#
#  batch_normalization_8 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 48, 48, 32)        9248
#
#  batch_normalization_9 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 24, 24, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 24, 24, 64)        18496
#
#  batch_normalization_10 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 24, 24, 64)        36928
#
#  batch_normalization_11 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_12 (Conv2D)          (None, 12, 12, 128)       73856
#
#  batch_normalization_12 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 12, 12, 128)       147584
#
#  batch_normalization_13 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_6 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_14 (Conv2D)          (None, 6, 6, 256)         295168
#
#  batch_normalization_14 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 6, 6, 256)         590080
#
#  batch_normalization_15 (Bat  (None, 6, 6, 256)        1024
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 3, 3, 256)         0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 64)                147520
#
#  batch_normalization_16 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  batch_normalization_17 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 1,328,743
# Trainable params: 1,326,567
# Non-trainable params: 2,176
# _________________________________________________________________

# %% [markdown]
# # Evalutating The Neural Network

# %%
def history_graph(history, epochs):

    plt.figure(figsize = (10,6))

    plt.subplot(121)
    plt.plot(history.history["accuracy"],label = "Train")
    plt.plot(history.history["val_accuracy"],label = "Validation")
    plt.legend(loc = "best")
    plt.title("Accuracy Score")
    plt.xticks(range(1,epochs+1,3), rotation = 90)

    plt.subplot(122)
    plt.plot(history.history["loss"],label = "Train")
    plt.plot(history.history["val_loss"],label = "Validation")
    plt.legend(loc = "best")
    plt.title("Loss Score")
    plt.xticks(range(1,epochs+1,3), rotation = 90)

    plt.tight_layout()
    plt.show()

def confusion_graph(y_test,y_pred):

    cm = confusion_matrix(y_test,y_pred)

    plt.figure(figsize = (10,5))
    sns.heatmap(cm, annot = True, fmt = "d", cbar = False, linewidth = 0.4, linecolor="white", annot_kws = {"size" : 20})
    plt.ylabel("Actual",fontsize = 15)
    plt.xlabel("Predicted",fontsize = 15)
    plt.title("Confusion Matrix Graph", fontsize = 15)
    plt.show()

# %%
load_model.evaluate(test_dataset)
# Out:
# 3589/3589 [==============================] - 50s 13ms/step - loss: 1.5148 - accuracy: 0.5779
# [1.5148497819900513, 0.5778768658638]

# %%
y_pred = load_model.predict(test_dataset)
y_pred = np.argmax(y_pred, axis = 1)

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %%
confusion_graph(test_dataset.classes , y_pred)

# %%
print(classification_report(test_dataset.classes , y_pred))
print()
print("Accuracy : {}".format(accuracy_score(test_dataset.classes , y_pred)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.56      0.57       491
#            1       0.56      0.65      0.61        55
#            2       0.48      0.46      0.47       528
#            3       0.76      0.88      0.82       879
#            4       0.25      0.18      0.21       626
#            5       0.52      0.54      0.53       594
#            6       0.72      0.74      0.73       416
#
#     accuracy                           0.58      3589
#    macro avg       0.55      0.57      0.56      3589
# weighted avg       0.56      0.58      0.56      3589
#
#
# Accuracy : 0.5778768459180831

# %% [markdown]
# # Classifying One Single Image

# %%
image = cv2.imread("/content/drive/MyDrive/OpenCV/Images/gabriel.png")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x7FB92F78DBD0>

# %%
image.shape
# Out:
# (300, 400, 3)

# %%
face_detector = cv2.CascadeClassifier("/content/drive/MyDrive/OpenCV/Cascades/haarcascade_frontalface_default.xml")
original_image = image.copy()
faces = face_detector.detectMultiScale(original_image)

x,y,w,h = faces[0]

roi = image[ y:y+h , x : x +w]
print(roi.shape)
cv2_imshow(roi)
# Out:
# (128, 128, 3)
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FB9378BAAD0>

# %%
roi = cv2.resize(roi, (48,48))
print(roi.shape)
cv2_imshow(roi)
# Out:
# (48, 48, 3)
# <PIL.Image.Image image mode=RGB size=48x48 at 0x7FB92F799410>

# %%
roi = np.expand_dims(roi, axis = 0)
roi.shape
# Out:
# (1, 48, 48, 3)

# %%
probs = load_model.predict(roi)
results = np.argmax(probs)
results
# Out:
# 0

# %%
probs
# Out:
# array([[1.0000000e+00, 8.6342781e-35, 3.2496090e-09, 0.0000000e+00,
#         4.0337122e-31, 1.8300194e-18, 0.0000000e+00]], dtype=float32)

# %%
test_dataset.class_indices
# Out:
# {'Angry': 0,
#  'Disgust': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
test_dataset.class_indices.keys()
# Out:
# dict_keys(['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise'])

# %% [markdown]
# # Classifying Multiple Images

# %%
image = cv2.imread("/content/drive/MyDrive/OpenCV/Images/faces_emotions.png")
faces = face_detector.detectMultiScale(image)
emotions = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

for (x,y,w,h) in faces :
    cv2.rectangle(image, (x,y), (x+w, y+h), (0,255,0),1)
    roi = image[y:y+h, x: x+w]
    #cv2_imshow(roi)
    roi = cv2.resize(roi , (48,48))
    roi = roi / 255
    roi = np.expand_dims(roi, axis = 0)
    #print(roi.shape)
    prediction = load_model.predict(roi)
    prediction = np.argmax(prediction)
   #print(prediction)
    cv2.putText(image, emotions[prediction], (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,255,0), 2, cv2.LINE_AA)

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=754x395 at 0x7FB92EBDCD50>

# %% [markdown]
# # Classifying Emotions In Videos

# %%
cap = cv2.VideoCapture("/content/drive/MyDrive/OpenCV/Videos/emotion_test01.mp4")
conn, frame = cap.read()

print(conn, frame.shape)
# Out:
# True (360, 640, 3)

# %%
save_path = "/content/emotion_test01_result.avi"
fourcc = cv2.VideoWriter_fourcc(*"XVID")
fps = 24
writer = cv2.VideoWriter(save_path, fourcc, fps , (frame.shape[1],frame.shape[0]))

# %%
face_detector = cv2.CascadeClassifier("/content/drive/MyDrive/OpenCV/Cascades/haarcascade_frontalface_default.xml")

while (cv2.waitKey(1) < 0):

    conn , frame = cap.read()

    if not conn:
        break

    faces = face_detector.detectMultiScale(frame,scaleFactor = 1.2, minNeighbors = 5, minSize = (30,30))

    if len(faces) > 0:
        for (x,y,w,h) in faces:
            frame =cv2.rectangle(frame,(x,y), (x + w, y +h), ( 0,255,0), 2)
            roi = frame[y:y+h, x:x+w]
            roi = cv2.resize(roi, (48,48))
            roi = roi / 255
            roi = np.expand_dims(roi ,axis = 0)
            prediction = load_model.predict(roi)

            if prediction is not None:
                result = np.argmax(prediction)
                cv2.putText(frame, emotions[result], (x, y - 10) , cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),1, cv2.LINE_AA)

    cv2_imshow(frame)
    writer.write(frame)

print("End")
cv2.destroyAllWindows()
cap.release()
writer.release()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
